# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
file_name = "./dataset/ecommerce_sales_34500.csv"
df = pd.read_csv(Path(file_name))

df.head()
# Out:
#   order_id customer_id product_id     category   price  discount  quantity  \
# 0  O100000      C17270    P234890         Home  164.08      0.15         1
# 1  O100001      C17603    P228204      Grocery   24.73      0.00         1
# 2  O100002      C10860    P213892  Electronics  175.58      0.05         1
# 3  O100003      C15390    P208689  Electronics   63.67      0.00         1
# 4  O100004      C15226    P228063         Home   16.33      0.15         1
#
#   payment_method  order_date  delivery_time_days region returned  \
# 0    Credit Card  2023-12-23                   4   West       No
# 1    Credit Card  2025-04-03                   6  South       No
# 2    Credit Card  2024-10-08                   4  North       No
# 3            UPI  2024-09-14                   6  South       No
# 4            COD  2024-12-21                   6   East       No
#
#    total_amount  shipping_cost  profit_margin  customer_age customer_gender
# ...

# %%
gender_map = {
    "Male": 0,
    "Female": 1,
    "Other": 2
}

df["customer_gender"] = df["customer_gender"].map(gender_map)

df.head()
# Out:
#   order_id customer_id product_id     category   price  discount  quantity  \
# 0  O100000      C17270    P234890         Home  164.08      0.15         1
# 1  O100001      C17603    P228204      Grocery   24.73      0.00         1
# 2  O100002      C10860    P213892  Electronics  175.58      0.05         1
# 3  O100003      C15390    P208689  Electronics   63.67      0.00         1
# 4  O100004      C15226    P228063         Home   16.33      0.15         1
#
#   payment_method  order_date  delivery_time_days region returned  \
# 0    Credit Card  2023-12-23                   4   West       No
# 1    Credit Card  2025-04-03                   6  South       No
# 2    Credit Card  2024-10-08                   4  North       No
# 3            UPI  2024-09-14                   6  South       No
# 4            COD  2024-12-21                   6   East       No
#
#    total_amount  shipping_cost  profit_margin  customer_age  customer_gender
# ...

# %%
df.isnull().sum()
# Out:
# order_id              0
# customer_id           0
# product_id            0
# category              0
# price                 0
# discount              0
# quantity              0
# payment_method        0
# order_date            0
# delivery_time_days    0
# region                0
# returned              0
# total_amount          0
# shipping_cost         0
# profit_margin         0
# customer_age          0
# customer_gender       0
# dtype: int64

# %%
return_map = {
    "Yes": 1,
    "No": 0
}
df["returned"] = df["returned"].map(return_map)
df.head()
# Out:
#   order_id customer_id product_id     category   price  discount  quantity  \
# 0  O100000      C17270    P234890         Home  164.08      0.15         1
# 1  O100001      C17603    P228204      Grocery   24.73      0.00         1
# 2  O100002      C10860    P213892  Electronics  175.58      0.05         1
# 3  O100003      C15390    P208689  Electronics   63.67      0.00         1
# 4  O100004      C15226    P228063         Home   16.33      0.15         1
#
#   payment_method  order_date  delivery_time_days region  returned  \
# 0    Credit Card  2023-12-23                   4   West         0
# 1    Credit Card  2025-04-03                   6  South         0
# 2    Credit Card  2024-10-08                   4  North         0
# 3            UPI  2024-09-14                   6  South         0
# 4            COD  2024-12-21                   6   East         0
#
#    total_amount  shipping_cost  profit_margin  customer_age  customer_gender
# ...

# %%
df["order_date"] = pd.to_datetime(df["order_date"])
df["order_month"] = df["order_date"].dt.month
df["order_year"] = df["order_date"].dt.year

df["order_day_of_week"] = df["order_date"].dt.dayofweek
df.head()
# Out:
#   order_id customer_id product_id     category   price  discount  quantity  \
# 0  O100000      C17270    P234890         Home  164.08      0.15         1
# 1  O100001      C17603    P228204      Grocery   24.73      0.00         1
# 2  O100002      C10860    P213892  Electronics  175.58      0.05         1
# 3  O100003      C15390    P208689  Electronics   63.67      0.00         1
# 4  O100004      C15226    P228063         Home   16.33      0.15         1
#
#   payment_method order_date  delivery_time_days region  returned  \
# 0    Credit Card 2023-12-23                   4   West         0
# 1    Credit Card 2025-04-03                   6  South         0
# 2    Credit Card 2024-10-08                   4  North         0
# 3            UPI 2024-09-14                   6  South         0
# 4            COD 2024-12-21                   6   East         0
#
#    total_amount  shipping_cost  profit_margin  customer_age  customer_gender  \
# ...

# %%
print("total_unique_rows",len(df))
print("total_number_of_customer_id",len(df["customer_id"].unique()))
print("total_number_of_order_id",len(df["order_id"].unique()))
# Out:
# total_unique_rows 34500
# total_number_of_customer_id 7903
# total_number_of_order_id 34500

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34500 entries, 0 to 34499
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            34500 non-null  str
#  1   customer_id         34500 non-null  str
#  2   product_id          34500 non-null  str
#  3   category            34500 non-null  str
#  4   price               34500 non-null  float64
#  5   discount            34500 non-null  float64
#  6   quantity            34500 non-null  int64
#  7   payment_method      34500 non-null  str
#  8   order_date          34500 non-null  datetime64[us]
#  9   delivery_time_days  34500 non-null  int64
#  10  region              34500 non-null  str
#  11  returned            34500 non-null  int64
#  12  total_amount        34500 non-null  float64
#  13  shipping_cost       34500 non-null  float64
#  14  profit_margin       34500 non-null  float64
#  15  customer_age        34500 non-null  int64
# ...

# %%
df["age_group"] = pd.cut(
    df["customer_age"],
    bins=[0, 25, 40, 60, 100],
    labels=["Young", "Adult", "Middle", "Senior"]
)
df.head()
# Out:
#   order_id customer_id product_id     category   price  discount  quantity  \
# 0  O100000      C17270    P234890         Home  164.08      0.15         1
# 1  O100001      C17603    P228204      Grocery   24.73      0.00         1
# 2  O100002      C10860    P213892  Electronics  175.58      0.05         1
# 3  O100003      C15390    P208689  Electronics   63.67      0.00         1
# 4  O100004      C15226    P228063         Home   16.33      0.15         1
#
#   payment_method order_date  delivery_time_days  ... returned  total_amount  \
# 0    Credit Card 2023-12-23                   4  ...        0        139.47
# 1    Credit Card 2025-04-03                   6  ...        0         24.73
# 2    Credit Card 2024-10-08                   4  ...        0        166.80
# 3            UPI 2024-09-14                   6  ...        0         63.67
# 4            COD 2024-12-21                   6  ...        0         13.88
#
# ...

# %%
df.to_csv("./dataset/ecommerce_cleaned.csv", index=False)
print("Saved!")
# Out:
# Saved!
